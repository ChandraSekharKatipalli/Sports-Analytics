# %%
#Importing Libraries
import pandas as pd 
import json

# %% [markdown]
# # Batter Records concatatination and exporting

# %%
Batter_records = pd.DataFrame()

# %%
with open('Final_Data/BatterData/Batter_2023.json') as f:
    data = json.load(f)

    all_records = []

    for rec in data:
        all_records.extend(rec['battingSummary'])

    Batter_2023 = pd.DataFrame(all_records)
    Batter_2023.tail()

# %%
Batter_2023
# Out:
#                      match teamInnings  battingPos          batsmanName  \
# 0    India Vs South Africa       India           1     Yashasvi Jaiswal
# 1    India Vs South Africa       India           2         Shubman Gill
# 2    India Vs South Africa       India           3          Tilak Varma
# 3    India Vs South Africa       India           4  Suryakumar Yadav(c)
# 4    India Vs South Africa       India           5          Rinku Singh
# ..                     ...         ...         ...                  ...
# 342     India Vs Sri Lanka   Sri Lanka           7    Wanindu Hasaranga
# 343     India Vs Sri Lanka   Sri Lanka           8  Chamika Karunaratne
# 344     India Vs Sri Lanka   Sri Lanka           9   Maheesh Theekshana
# 345     India Vs Sri Lanka   Sri Lanka          10        Kasun Rajitha
# 346     India Vs Sri Lanka   Sri Lanka          11   Dilshan Madushanka
#
#                            dismissal runs balls 4s 6s      SR
# ...

# %%
Batter_2023['Year'] = '2023'

# %%
with open('Final_Data/BatterData/Batter_2022.json') as f:
    data = json.load(f)

    all_records = []

    for rec in data:
        all_records.extend(rec['battingSummary'])

    Batter_2022 = pd.DataFrame(all_records)
    Batter_2022.tail()

Batter_2022['Year'] = '2022'
Batter_2022
# Out:
#                     match  teamInnings  battingPos       batsmanName  \
# 0    New Zealand Vs India  New Zealand           1        Finn Allen
# 1    New Zealand Vs India  New Zealand           2   Devon Conwayâ€
# 2    New Zealand Vs India  New Zealand           3      Mark Chapman
# 3    New Zealand Vs India  New Zealand           4    Glenn Phillips
# 4    New Zealand Vs India  New Zealand           5    Daryl Mitchell
# ..                    ...          ...         ...               ...
# 605  West Indies Vs India        India           2      Ishan Kishan
# 606  West Indies Vs India        India           3       Virat Kohli
# 607  West Indies Vs India        India           4   Rishabh Pantâ€
# 608  West Indies Vs India        India           5  Suryakumar Yadav
# 609  West Indies Vs India        India           6    Venkatesh Iyer
#
#                              dismissal runs balls 4s 6s      SR  Year
# 0                 lbw b Arshdeep Singh    3     4  0  0   75.00  2022
# ...

# %%
with open('Final_Data/BatterData/Batter_2021.json') as f:
    data = json.load(f)

    all_records = []

    for rec in data:
        all_records.extend(rec['battingSummary'])

    Batter_2021 = pd.DataFrame(all_records)
    Batter_2021.tail()

Batter_2021['Year'] = '2021'
Batter_2021
# Out:
#                     match teamInnings  battingPos       batsmanName  \
# 0    India Vs New Zealand       India           1   Rohit Sharma(c)
# 1    India Vs New Zealand       India           2      Ishan Kishan
# 2    India Vs New Zealand       India           3  Suryakumar Yadav
# 3    India Vs New Zealand       India           4   Rishabh Pantâ€
# 4    India Vs New Zealand       India           5      Shreyas Iyer
# ..                    ...         ...         ...               ...
# 227      India Vs England       India           9        Axar Patel
# 228      India Vs England     England           1         Jason Roy
# 229      India Vs England     England           2    Jos Buttlerâ€
# 230      India Vs England     England           3       Dawid Malan
# 231      India Vs England     England           4    Jonny Bairstow
#
#                    dismissal runs balls 4s 6s      SR  Year
# 0                c & b Sodhi   56    31  5  3  180.64  2021
# ...

# %%
with open('Final_Data/BatterData/Batter_2020.json') as f:
    data = json.load(f)

    all_records = []

    for rec in data:
        all_records.extend(rec['battingSummary'])

    Batter_2020 = pd.DataFrame(all_records)
    Batter_2020.tail()

Batter_2020['Year'] = '2020'
Batter_2020
# Out:
#                   match teamInnings  battingPos       batsmanName  \
# 0    Australia Vs India   Australia           1   Matthew Wadeâ€
# 1    Australia Vs India   Australia           2    Aaron Finch(c)
# 2    Australia Vs India   Australia           3      Steven Smith
# 3    Australia Vs India   Australia           4     Glenn Maxwell
# 4    Australia Vs India   Australia           5  Moises Henriques
# ..                  ...         ...         ...               ...
# 151  Sri Lanka Vs India       India           1          KL Rahul
# 152  Sri Lanka Vs India       India           2    Shikhar Dhawan
# 153  Sri Lanka Vs India       India           3      Shreyas Iyer
# 154  Sri Lanka Vs India       India           4    Virat Kohli(c)
# 155  Sri Lanka Vs India       India           5   Rishabh Pantâ€
#
#                         dismissal runs balls 4s 6s      SR  Year
# 0                    lbw b Thakur   80    53  7  2  150.94  2020
# ...

# %%
with open('Final_Data/BatterData/Batter_2019.json') as f:
    data = json.load(f)

    all_records = []

    for rec in data:
        all_records.extend(rec['battingSummary'])

    Batter_2019 = pd.DataFrame(all_records)
    Batter_2019.tail()

Batter_2019['Year'] = '2019'
Batter_2019
# Out:
#                     match teamInnings  battingPos        batsmanName  \
# 0    India Vs West Indies       India           1       Rohit Sharma
# 1    India Vs West Indies       India           2           KL Rahul
# 2    India Vs West Indies       India           3    Rishabh Pantâ€
# 3    India Vs West Indies       India           4     Virat Kohli(c)
# 4    India Vs West Indies       India           5       Shreyas Iyer
# ..                    ...         ...         ...                ...
# 226  New Zealand Vs India       India           7      Hardik Pandya
# 227  New Zealand Vs India       India           8      Krunal Pandya
# 228  New Zealand Vs India       India           9  Bhuvneshwar Kumar
# 229  New Zealand Vs India       India          10   Yuzvendra Chahal
# 230  New Zealand Vs India       India          11      Khaleel Ahmed
#
#                    dismissal runs balls 4s 6s      SR  Year
# 0         c Walsh b Williams   71    34  6  5  208.82  2019
# ...

# %%
with open('Final_Data/BatterData/Batter_2018.json') as f:
    data = json.load(f)

    all_records = []

    for rec in data:
        all_records.extend(rec['battingSummary'])

    Batter_2018 = pd.DataFrame(all_records)
    Batter_2018.tail()

Batter_2018['Year'] = '2018'
Batter_2018
# Out:
#                      match   teamInnings  battingPos         batsmanName  \
# 0       Australia Vs India     Australia           1        D'Arcy Short
# 1       Australia Vs India     Australia           2      Aaron Finch(c)
# 2       Australia Vs India     Australia           3       Glenn Maxwell
# 3       Australia Vs India     Australia           4       Ben McDermott
# 4       Australia Vs India     Australia           5       Alex Careyâ€
# ..                     ...           ...         ...                 ...
# 276  India Vs South Africa  South Africa           7  Andile Phehlukwayo
# 277  India Vs South Africa  South Africa           8        Chris Morris
# 278  India Vs South Africa  South Africa           9       Dane Paterson
# 279  India Vs South Africa  South Africa          10         Junior Dala
# 280  India Vs South Africa  South Africa          11      Tabraiz Shamsi
#
#                      dismissal runs balls 4s 6s      SR  Year
# ...

# %%
Batter_records = pd.concat([Batter_2023, Batter_2022, Batter_2021, Batter_2020, Batter_2019, Batter_2018], ignore_index=True)
Batter_records
# Out:
#                       match   teamInnings  battingPos          batsmanName  \
# 0     India Vs South Africa         India           1     Yashasvi Jaiswal
# 1     India Vs South Africa         India           2         Shubman Gill
# 2     India Vs South Africa         India           3          Tilak Varma
# 3     India Vs South Africa         India           4  Suryakumar Yadav(c)
# 4     India Vs South Africa         India           5          Rinku Singh
# ...                     ...           ...         ...                  ...
# 1852  India Vs South Africa  South Africa           7   Andile Phehlukwayo
# 1853  India Vs South Africa  South Africa           8         Chris Morris
# 1854  India Vs South Africa  South Africa           9        Dane Paterson
# 1855  India Vs South Africa  South Africa          10          Junior Dala
# 1856  India Vs South Africa  South Africa          11       Tabraiz Shamsi
#
#                       dismissal runs balls 4s 6s      SR  Year
# ...

# %%
Batter_records.to_csv('BatterRecords.csv', index=False)

# %% [markdown]
# # Bowler Data concatination and Exporting

# %%
Bowler_Records = pd.DataFrame()

# %%
with open('Final_Data/BowlerData/Bowler_2023.json') as f:
    data = json.load(f)

    all_records = []

    for rec in data:
        all_records.extend(rec['bowlingSummary'])

    Bowler_2023 = pd.DataFrame(all_records)
    Bowler_2023.tail()

Bowler_2023['Year'] = '2023'
Bowler_2023
# Out:
#                      match   bowlingTeam          bowlerName overs maiden  \
# 0    India Vs South Africa  South Africa        Marco Jansen     3      0
# 1    India Vs South Africa  South Africa     Lizaad Williams     3      0
# 2    India Vs South Africa  South Africa      Gerald Coetzee   3.3      0
# 3    India Vs South Africa  South Africa  Andile Phehlukwayo     3      0
# 4    India Vs South Africa  South Africa      Tabraiz Shamsi     4      0
# ..                     ...           ...                 ...   ...    ...
# 248     India Vs Sri Lanka         India         Shivam Mavi     4      0
# 249     India Vs Sri Lanka         India         Umran Malik     4      0
# 250     India Vs Sri Lanka         India    Yuzvendra Chahal     2      0
# 251     India Vs Sri Lanka         India       Harshal Patel     4      0
# 252     India Vs Sri Lanka         India          Axar Patel     3      0
#
#     runs wickets economy  0s 4s 6s wides noBalls  Year
# ...

# %%
with open('Final_Data/BowlerData/Bowler_2022.json') as f:
    data = json.load(f)

    all_records = []

    for rec in data:
        all_records.extend(rec['bowlingSummary'])

    Bowler_2022 = pd.DataFrame(all_records)
    Bowler_2022.tail()

Bowler_2022['Year'] = '2022'
Bowler_2022
# Out:
#                     match  bowlingTeam         bowlerName overs maiden runs  \
# 0    New Zealand Vs India        India  Bhuvneshwar Kumar     4      0   35
# 1    New Zealand Vs India        India     Arshdeep Singh     4      0   37
# 2    New Zealand Vs India        India     Mohammed Siraj     4      0   17
# 3    New Zealand Vs India        India       Deepak Hooda     1      0    3
# 4    New Zealand Vs India        India   Yuzvendra Chahal     3      0   35
# ..                    ...          ...                ...   ...    ...  ...
# 450  West Indies Vs India  West Indies   Romario Shepherd     3      0   24
# 451  West Indies Vs India  West Indies        Odean Smith     2      0   31
# 452  West Indies Vs India  West Indies       Akeal Hosein     4      0   34
# 453  West Indies Vs India  West Indies       Roston Chase     4      0   14
# 454  West Indies Vs India  West Indies       Fabian Allen   1.5      0   23
#
#     wickets economy  0s 4s 6s wides noBalls  Year
# ...

# %%
with open('Final_Data/BowlerData/Bowler_2021.json') as f:
    data = json.load(f)

    all_records = []

    for rec in data:
        all_records.extend(rec['bowlingSummary'])

    Bowler_2021 = pd.DataFrame(all_records)
    Bowler_2021.tail()

Bowler_2021['Year'] = '2021'
Bowler_2021
# Out:
#                     match  bowlingTeam         bowlerName overs maiden runs  \
# 0    India Vs New Zealand  New Zealand        Trent Boult     4      0   31
# 1    India Vs New Zealand  New Zealand         Adam Milne     4      0   47
# 2    India Vs New Zealand  New Zealand    Lockie Ferguson     4      0   45
# 3    India Vs New Zealand  New Zealand   Mitchell Santner     4      0   27
# 4    India Vs New Zealand  New Zealand          Ish Sodhi     4      0   31
# ..                    ...          ...                ...   ...    ...  ...
# 178      India Vs England        India  Bhuvneshwar Kumar     2      0   15
# 179      India Vs England        India   Yuzvendra Chahal     4      0   44
# 180      India Vs England        India     Shardul Thakur     2      0   16
# 181      India Vs England        India      Hardik Pandya     2      0   13
# 182      India Vs England        India  Washington Sundar   2.3      0   18
#
#     wickets economy  0s 4s 6s wides noBalls  Year
# ...

# %%
with open('Final_Data/BowlerData/Bowler_2020.json') as f:
    data = json.load(f)

    all_records = []

    for rec in data:
        all_records.extend(rec['bowlingSummary'])

    Bowler_2020 = pd.DataFrame(all_records)
    Bowler_2020.tail()

Bowler_2020['Year'] = '2020'
Bowler_2020
# Out:
#                   match bowlingTeam           bowlerName overs maiden runs  \
# 0    Australia Vs India       India        Deepak Chahar     4      0   34
# 1    Australia Vs India       India    Washington Sundar     4      0   34
# 2    Australia Vs India       India          T Natarajan     4      0   33
# 3    Australia Vs India       India     Yuzvendra Chahal     4      0   41
# 4    Australia Vs India       India       Shardul Thakur     4      0   43
# ..                  ...         ...                  ...   ...    ...  ...
# 106  Sri Lanka Vs India   Sri Lanka       Lasith Malinga     4      0   41
# 107  Sri Lanka Vs India   Sri Lanka        Lahiru Kumara   3.3      0   30
# 108  Sri Lanka Vs India   Sri Lanka  Dhananjaya de Silva     2      0   15
# 109  Sri Lanka Vs India   Sri Lanka        Dasun Shanaka     4      0   26
# 110  Sri Lanka Vs India   Sri Lanka    Wanindu Hasaranga     4      0   30
#
#     wickets economy 0s 4s 6s wides noBalls  Year
# ...

# %%
with open('Final_Data/BowlerData/Bowler_2019.json') as f:
    data = json.load(f)

    all_records = []

    for rec in data:
        all_records.extend(rec['bowlingSummary'])

    Bowler_2019 = pd.DataFrame(all_records)
    Bowler_2019.tail()

Bowler_2019['Year'] = '2019'
Bowler_2019
# Out:
#                     match  bowlingTeam        bowlerName overs maiden runs  \
# 0    India Vs West Indies  West Indies  Sheldon Cottrell     4      0   40
# 1    India Vs West Indies  West Indies      Jason Holder     4      0   54
# 2    India Vs West Indies  West Indies      Khary Pierre     2      0   35
# 3    India Vs West Indies  West Indies  Kesrick Williams     4      0   37
# 4    India Vs West Indies  West Indies      Hayden Walsh     4      0   38
# ..                    ...          ...               ...   ...    ...  ...
# 182  New Zealand Vs India  New Zealand  Scott Kuggeleijn     2      0   34
# 183  New Zealand Vs India  New Zealand   Lockie Ferguson     4      0   22
# 184  New Zealand Vs India  New Zealand  Mitchell Santner     4      0   24
# 185  New Zealand Vs India  New Zealand    Daryl Mitchell   2.2      0   13
# 186  New Zealand Vs India  New Zealand         Ish Sodhi     3      0   26
#
#     wickets economy  0s 4s 6s wides noBalls  Year
# ...

# %%
with open('Final_Data/BowlerData/Bowler_2018.json') as f:
    data = json.load(f)

    all_records = []

    for rec in data:
        all_records.extend(rec['bowlingSummary'])

    Bowler_2018 = pd.DataFrame(all_records)
    Bowler_2018.tail()

Bowler_2018['Year'] = '2023'
Bowler_2018
# Out:
#                      match bowlingTeam         bowlerName overs maiden runs  \
# 0       Australia Vs India       India  Bhuvneshwar Kumar     4      0   33
# 1       Australia Vs India       India      Khaleel Ahmed     4      0   35
# 2       Australia Vs India       India     Jasprit Bumrah     4      0   38
# 3       Australia Vs India       India      Kuldeep Yadav     4      0   19
# 4       Australia Vs India       India      Krunal Pandya     4      0   36
# ..                     ...         ...                ...   ...    ...  ...
# 201  India Vs South Africa       India  Bhuvneshwar Kumar     4      0   24
# 202  India Vs South Africa       India     Jaydev Unadkat     4      0   33
# 203  India Vs South Africa       India     Jasprit Bumrah     4      0   32
# 204  India Vs South Africa       India      Hardik Pandya     4      0   45
# 205  India Vs South Africa       India   Yuzvendra Chahal     4      0   39
#
#     wickets economy  0s 4s 6s wides noBalls  Year
# ...

# %%
Bowler_Records = pd.concat([Bowler_2023, Bowler_2022, Bowler_2021, Bowler_2020, Bowler_2019, Bowler_2018], ignore_index=True)
Bowler_Records
# Out:
#                       match   bowlingTeam          bowlerName overs maiden  \
# 0     India Vs South Africa  South Africa        Marco Jansen     3      0
# 1     India Vs South Africa  South Africa     Lizaad Williams     3      0
# 2     India Vs South Africa  South Africa      Gerald Coetzee   3.3      0
# 3     India Vs South Africa  South Africa  Andile Phehlukwayo     3      0
# 4     India Vs South Africa  South Africa      Tabraiz Shamsi     4      0
# ...                     ...           ...                 ...   ...    ...
# 1390  India Vs South Africa         India   Bhuvneshwar Kumar     4      0
# 1391  India Vs South Africa         India      Jaydev Unadkat     4      0
# 1392  India Vs South Africa         India      Jasprit Bumrah     4      0
# 1393  India Vs South Africa         India       Hardik Pandya     4      0
# 1394  India Vs South Africa         India    Yuzvendra Chahal     4      0
#
#      runs wickets economy  0s 4s 6s wides noBalls  Year
# ...

# %%
Bowler_Records.to_csv('BowlerRecords.csv', index=False)

# %% [markdown]
# # Match Data Concatination and exporting

# %%
Match_Records = pd.DataFrame()

# %%
with open('Final_Data/MatchData/MatchResults_2023.json') as f:
    data = json.load(f)

MatchResults_2023 = pd.DataFrame(data[0]['matchSummary'])
MatchResults_2023
# Out:
#            team1        team2        winner     margin              ground  \
# 0   South Africa        India  South Africa  5 wickets            Gqeberha
# 1          India    Australia         India     6 runs           Bengaluru
# 2          India    Australia         India    20 runs              Raipur
# 3          India    Australia     Australia  5 wickets            Guwahati
# 4          India    Australia         India    44 runs  Thiruvananthapuram
# 5          India    Australia         India  2 wickets       Visakhapatnam
# 6    Afghanistan        India     no result          -            Hangzhou
# 7     Bangladesh        India         India  9 wickets            Hangzhou
# 8          India        Nepal         India    23 runs            Hangzhou
# 9        Ireland        India         India    33 runs   Dublin (Malahide)
# 10       Ireland        India         India     2 runs   Dublin (Malahide)
# ...

# %%
with open('Final_Data/MatchData/MatchResults_2022.json') as f:
    data = json.load(f)

MatchResults_2022 = pd.DataFrame(data[0]['matchSummary'])
MatchResults_2022
# Out:
#           team1         team2        winner      margin              ground  \
# 0   New Zealand         India          tied           -              Napier
# 1   New Zealand         India         India     65 runs     Mount Maunganui
# 2       England         India       England  10 wickets            Adelaide
# 3         India      Zimbabwe         India     71 runs           Melbourne
# 4    Bangladesh         India         India      5 runs            Adelaide
# 5         India  South Africa  South Africa   5 wickets               Perth
# 6         India   Netherlands         India     56 runs              Sydney
# 7         India      Pakistan         India   4 wickets           Melbourne
# 8         India  South Africa  South Africa     49 runs              Indore
# 9         India  South Africa         India     16 runs            Guwahati
# 10        India  South Africa         India   8 wickets  Thiruvananthapuram
# ...

# %%
with open('Final_Data/MatchData/MatchResults_2021.json') as f:
    data = json.load(f)

MatchResults_2021 = pd.DataFrame(data[0]['matchSummary'])
MatchResults_2021
# Out:
#           team1        team2       winner      margin         ground  \
# 0         India  New Zealand        India     73 runs   Eden Gardens
# 1         India  New Zealand        India   7 wickets         Ranchi
# 2         India  New Zealand        India   5 wickets         Jaipur
# 3         India      Namibia        India   9 wickets    Dubai (DSC)
# 4         India     Scotland        India   8 wickets    Dubai (DSC)
# 5   Afghanistan        India        India     66 runs      Abu Dhabi
# 6         India  New Zealand  New Zealand   8 wickets    Dubai (DSC)
# 7         India     Pakistan     Pakistan  10 wickets    Dubai (DSC)
# 8     Sri Lanka        India    Sri Lanka   7 wickets  Colombo (RPS)
# 9     Sri Lanka        India    Sri Lanka   4 wickets  Colombo (RPS)
# 10    Sri Lanka        India        India     38 runs  Colombo (RPS)
# 11        India      England        India     36 runs      Ahmedabad
# 12        India      England        India      8 runs      Ahmedabad
# ...

# %%
with open('Final_Data/MatchData/MatchResults_2020.json') as f:
    data = json.load(f)

MatchResults_2020 = pd.DataFrame(data[0]['matchSummary'])
MatchResults_2020
# Out:
#           team1      team2     winner     margin           ground  \
# 0     Australia      India  Australia    12 runs           Sydney
# 1     Australia      India      India  6 wickets           Sydney
# 2     Australia      India      India    11 runs         Canberra
# 3   New Zealand      India      India     7 runs  Mount Maunganui
# 4   New Zealand      India       tied          -       Wellington
# 5   New Zealand      India       tied          -         Hamilton
# 6   New Zealand      India      India  7 wickets         Auckland
# 7   New Zealand      India      India  6 wickets         Auckland
# 8         India  Sri Lanka      India    78 runs             Pune
# 9         India  Sri Lanka      India  7 wickets           Indore
# 10        India  Sri Lanka  no result          -         Guwahati
#
#        matchDate    scorecard
# 0    Dec 8, 2020  T20I # 1116
# 1    Dec 6, 2020  T20I # 1115
# 2    Dec 4, 2020  T20I # 1114
# 3    Feb 2, 2020  T20I # 1037
# ...

# %%
with open('Final_Data/MatchData/MatchResults_2019.json') as f:
    data = json.load(f)

MatchResults_2019 = pd.DataFrame(data[0]['matchSummary'])
MatchResults_2019
# Out:
#           team1         team2        winner     margin              ground  \
# 0         India   West Indies         India    67 runs            Wankhede
# 1         India   West Indies   West Indies  8 wickets  Thiruvananthapuram
# 2         India   West Indies         India  6 wickets           Hyderabad
# 3         India    Bangladesh         India    30 runs              Nagpur
# 4         India    Bangladesh         India  8 wickets              Rajkot
# 5         India    Bangladesh    Bangladesh  7 wickets               Delhi
# 6         India  South Africa  South Africa  9 wickets           Bengaluru
# 7         India  South Africa         India  7 wickets              Mohali
# 8   West Indies         India         India  7 wickets          Providence
# 9         India   West Indies         India    22 runs          Lauderhill
# 10        India   West Indies         India  4 wickets          Lauderhill
# ...

# %%
with open('Final_Data/MatchData/MatchResults_2018.json') as f:
    data = json.load(f)

MatchResults_2018 = pd.DataFrame(data[0]['matchSummary'])
MatchResults_2018
# Out:
#            team1        team2        winner     margin             ground  \
# 0      Australia        India         India  6 wickets             Sydney
# 1      Australia        India     no result          -          Melbourne
# 2      Australia        India     Australia     4 runs           Brisbane
# 3          India  West Indies         India  6 wickets            Chennai
# 4          India  West Indies         India    71 runs            Lucknow
# 5          India  West Indies         India  5 wickets       Eden Gardens
# 6        England        India         India  7 wickets            Bristol
# 7        England        India       England  5 wickets            Cardiff
# 8        England        India         India  8 wickets         Manchester
# 9        Ireland        India         India   143 runs  Dublin (Malahide)
# 10       Ireland        India         India    76 runs  Dublin (Malahide)
# 11    Bangladesh        India         India  4 wickets      Colombo (RPS)
# ...

# %%
Match_Records = pd.concat([MatchResults_2023, MatchResults_2022, MatchResults_2021, MatchResults_2020, MatchResults_2019, MatchResults_2018], ignore_index=True)
Match_Records
# Out:
#             team1      team2        winner     margin              ground  \
# 0    South Africa      India  South Africa  5 wickets            Gqeberha
# 1           India  Australia         India     6 runs           Bengaluru
# 2           India  Australia         India    20 runs              Raipur
# 3           India  Australia     Australia  5 wickets            Guwahati
# 4           India  Australia         India    44 runs  Thiruvananthapuram
# ..            ...        ...           ...        ...                 ...
# 119    Bangladesh      India         India  6 wickets       Colombo (RPS)
# 120     Sri Lanka      India     Sri Lanka  5 wickets       Colombo (RPS)
# 121  South Africa      India         India     7 runs           Cape Town
# 122  South Africa      India  South Africa  6 wickets           Centurion
# 123  South Africa      India         India    28 runs        Johannesburg
#
#         matchDate    scorecard
# 0    Dec 12, 2023  T20I # 2396
# ...

# %%
Match_Records.to_csv('MatchRecords.csv', index=False)
